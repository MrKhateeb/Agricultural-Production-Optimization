# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact #for interactive analysis

# %%
agd=pd.read_csv(r"C:\Users\aquib\Desktop\DATA SET\DataSet\Farming.csv")

# %%
agd.head(10)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6  69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7  94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8  89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9  68  58  38    23.223974  83.033227  6.336254  221.209196  rice

# %%
#Shape of the dataset
agd.shape
# Out:
# (2200, 8)

# %%
print("Number of columns Are :",agd.shape[0])
print("Number of Rows Are :", agd.shape[1])
# Out:
# Number of columns Are : 2200
# Number of Rows Are : 8

# %%
#Checking the head of the dataset
agd.head(5)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
agd.tail(5)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
#Checking the missing values
agd.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#Checking the crops present
agd['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
print("Number of corps Are :" , agd['label'].nunique())
# Out:
# Number of corps Are : 22

# %%
sns.displot(x=agd['rainfall'] , aspect=3)

# %%
agd.head(2)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice

# %%
# Set up the visual style for seaborn
sns.set(style="whitegrid")

# 1. Distribution of Nutrients (N, P, K) by Crop Type
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
sns.boxplot(x='label', y='N', data=agd , color='r')
plt.xticks(rotation=90)
plt.title('Distribution of Nitrogen (N) by Crop')

plt.subplot(1, 3, 2)
sns.boxplot(x='label', y='P', data=agd)
plt.xticks(rotation=90)
plt.title('Distribution of Phosphorus (P) by Crop')

plt.subplot(1, 3, 3)
sns.boxplot(x='label', y='K', data=agd)
plt.xticks(rotation=90)
plt.title('Distribution of Potassium (K) by Crop')

plt.tight_layout()
plt.show()

# %%
#Checking average climatic and soil requirements
print("Average Ratio of Nitrogen in the Soil : {0:.2f}".format(agd['N'].mean()))
print("Average Ratio of Phosphorous in the soil : {0:.2f}".format(agd['P'].mean()))
print("Average Ratio of Potassium in the soil : {0:.2f}".format(agd['K'].mean()))
print("Average Ratio of Temperature in soil : {0:.2f}".format(agd['temperature'].mean()))
print("Average Ratio of Humidity in soil : {0:.2f}".format(agd['humidity'].mean()))
print("Average Ratio of PH Level in soil".format(agd['ph'].mean()))
print("Average Ratio of Rain Fall in mm {0:.2f}".format(agd['rainfall'].mean()))
# Out:
# Average Ratio of Nitrogen in the Soil : 50.55
# Average Ratio of Phosphorous in the soil : 53.36
# Average Ratio of Potassium in the soil : 48.15
# Average Ratio of Temperature in soil : 25.62
# Average Ratio of Humidity in soil : 71.48
# Average Ratio of PH Level in soil
# Average Ratio of Rain Fall in mm 103.46

# %%
#Checking the detailed statistics for each crop

# %%
from ipywidgets import interact

# %%
#@interact
#def summary(crops = list(agd['label'].value_counts().index)):
#    x= agd[agd['label'] == crops]

# %%
#@interact
#def summm(crops = ['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#       'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#       'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#       'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee']):
#    x=agd[agd['label'] == crops]

# %%
@interact
def summ(crops=list(agd['label'].unique())):
    xs=agd[agd['label'] == crops]
    print("---------------------------------------------")
    print( "Statistics of Nitrogen" )
    print('Nitrogen Reaquired Min:' , xs['N'].min())
    print('Nitrogen Reaquired Avg:' , xs['N'].mean())
    print('Nitrogen Reaquired Max:' , xs['N'].max())
    print('----------------------------------------------')
    print("Stats for Phosphorous ")
    print('Phosphorous Required Min:' , xs['P'].min())
    print('Phosphorous Required Avg:' , xs['P'].mean())
    print('Phosphorous Required Max:' , xs['P'].max())
    print('----------------------------------------------')
    print('Potassium Required Min:' , xs['K'].min())
    print('Potassium Required Avg:' , xs['K'].mean())
    print('Potassium Required Max:' , xs['K'].max())
    print('----------------------------------------------')
    print("Temperature Required Min: {0:.2f}".format(xs['temperature'].min()))
    print("Temperature Required Avg: {0:.2f}".format(xs['temperature'].mean()))
    print("Temperature Required Max: {0:.2f}".format(xs['temperature'].max()))
    print('---------------------------------------------------')
    print("Humidity Required Min: {0:.2f}".format( xs['humidity'].min()))
    print("Humidity Required Avg: {0:.2f}".format( xs['humidity'].mean()))
    print("Humidity Required Max: {0:.2f}".format( xs['humidity'].max()))
    print("...........................................")
    print("Statistics for Rainfall")
    print("Rainfall required in mm Min: {0:.2f}".format(xs['rainfall'].min()))
    print("Rainfall required in mm Avg: {0:.2f}".format(xs['rainfall'].mean()))
    print("Rainfall required in mm Max: {0:.2f}".format(xs['rainfall'].max()))
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'maize', 'chickpea', 'kidneybeans', 'pige…

# %%
#agd['label'].unique()

# %%
agd.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %% [markdown]
# Comparing Average requirement and conditions for each crop

# %%
@interact           
def compare(con=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']):
    print("Average Value for" , con , "is {0:.2f}".format(agd[con].mean()))
    print(" ")
    print("Rice : {0:.2f}" .format(agd[agd['label'] == 'rice'][con].mean()))
    print(" ")
    print("Maize : {0:.2f}".format(agd[agd['label'] == 'maize'][con].mean()))
    print(" ")
    print("Chickpea : {0:.2f}".format(agd[agd['label'] == 'chickpea'][con].mean()))
    print(" ")
    print("Kidneybeans : {0:.2f}".format(agd[agd['label'] == 'kidneybeans'][con].mean()))
    print(" ")
    print("Pigeonpeas : {0:.2f}".format(agd[agd['label']=='pigeonpeas'][con].mean()))
    print(" ")
    print("Mothbeans : {0:.2f}".format(agd[agd['label'] == 'mothbeans'][con].mean()))
    print(" ")
    print("Mungbean : {0:.2f}".format(agd[agd['label'] == 'mungbean'][con].mean()))
    print(" ")
    print("Blackgram : {0:.2f}".format(agd[agd['label'] == 'blackgram'][con].mean()))
    print(" ")
    print("Lentil : {0:.2f}".format(agd[agd['label'] == 'lentil'][con].mean()))
    print(" ")
    print("Pomegranate : {0:.2f}".format(agd[agd['label'] == 'pomegranate'][con].mean()))
    print(" ")
    print("Banana : {0:.2f}".format(agd[agd['label'] == 'banana'][con].mean()))
    print(" ")
    print("Mango : {0:.2f}".format(agd[agd['label'] == 'mango'][con].mean()))
    print(" ")
    print("Grapes : {0:.2f}".format(agd[agd['label'] == 'grapes'][con].mean()))
    print(" ")
    print("Watermelon : {0:.2f}".format(agd[agd['label'] == 'watermelon'][con].mean()))
    print(" ")
    print("Muskmelon : {0:.2f}".format(agd[agd['label'] == 'muskmelon'][con].mean()))
    print(" ")
    print("Apple : {0:.2f}".format(agd[agd['label'] == 'apple'][con].mean()))
    print(" ")
    print("Orange : {0:.2f}".format(agd[agd['label'] == 'orange'][con].mean()))
    print(" ")
    print("Papaya : {0:.2f}".format(agd[agd['label'] == 'papaya'][con].mean()))
    print(" ")
    print("Coconut : {0:.2f}".format(agd[agd['label'] == 'coconut'][con].mean()))
    print(" ")
    print("Cotton : {0:.2f}".format(agd[agd['label'] == 'cotton'][con].mean()))
    print(" ")
    print("Jute : {0:.2f}".format(agd[agd['label'] == 'jute'][con].mean()))
    print(" ")
    print("Coffee : {0:.2f}".format(agd[agd['label'] == 'coffee'][con].mean()))
# Out:
# interactive(children=(Dropdown(description='con', options=('N', 'P', 'K', 'temperature', 'humidity', 'ph', 'ra…

# %%
agd['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
#Checking the below and above Average Conditions

@interact
def comparee(Con=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']):
    print("Crops which required Greater than Average" , Con , '\n')
    print(" ")
    print(agd[agd[Con] > agd[Con].mean()]['label'].unique())
    print(" ")
    print("Crops which required Less than Average" , Con , '\n')
    print(agd[agd[Con] <= agd[Con].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='Con', options=('N', 'P', 'K', 'temperature', 'humidity', 'ph', 'ra…

# %%
agd.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %% [markdown]
# # Distribution for Agricultural Conditions

# %%
sns.displot(agd['K'], color='gray', kde='True')
plt.title("Distribution of Calssium") 
plt.xlabel('Calssium')
plt.grid()
plt.show()

# %%
sns.displot(agd['N'],color='red' , kde="Tru")
plt.title("Distribution of Nitrogen")
plt.xlabel('Nitrogen')
plt.grid()
plt.show()

# %%
sns.displot(agd['P'], kde=True)
plt.title("Distribution of Phosphorous")
plt.xlabel('Phosphorous')
plt.grid()
plt.show()

# %%
sns.displot(agd['humidity'],kde=True, color='yellow')
plt.title("Distribution of humidity")
plt.xlabel('humidity')
plt.grid()
plt.show()

# %%
sns.displot(agd['ph'],kde="True")
plt.title("Distribution of Ph level")
plt.xlabel('Ph')
plt.grid()
plt.show()

# %%
sns.displot(agd['rainfall'], color='black' , kde=True)
plt.title("Distribution of Rain Fall")
plt.xlabel('RainFall')
plt.grid()
plt.show()

# %%
sns.displot(agd['temperature'], kde=True)
plt.title("Distribution of Temperature")
plt.xlabel('temperature')
plt.grid()
plt.show()

# %%
agd['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
@interact
def comparee(Crops_name=['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
       'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
       'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
       'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee']):
    
    filer_data = agd[agd['label'] == Crops_name]
   # Temperature vs. Humidity colored by Crop Type
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='temperature', y='humidity', hue='label', palette='tab10', data=filer_data)
    plt.title('Temperature vs. Humidity by Crop Type')
    plt.show()
# Out:
# interactive(children=(Dropdown(description='Crops_name', options=('rice', 'maize', 'chickpea', 'kidneybeans', …

# %%
# Temperature vs. Humidity colored by Crop Type
plt.figure(figsize=(10, 6))
sns.scatterplot(x='temperature', y='humidity', hue='label', palette='tab10', data=agd)
plt.title('Temperature vs. Humidity by Crop Type')
plt.show()

# %%
dfe = agd.drop('label' , axis=1)

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 6))
corr = dfe.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
agd['temperature'].describe()
# Out:
# count    2200.000000
# mean       25.616244
# std         5.063749
# min         8.825675
# 25%        22.769375
# 50%        25.598693
# 75%        28.561654
# max        43.675493
# Name: temperature, dtype: float64

# %%
#Checking that crops those have unusual requirements

print("Some Interesting Patterns")
print("...........................................")
print("Crops that require very High Ratio of Nitrogen Content in Soil:", agd[agd['N'] > 120]['label'].unique())
print("Crops that require ver High Ratio of Phosphorous Content in Soil:", agd[agd['P'] > 100]['label'].unique())
print("Crops thet required very High Ratio of Potassium Content in Soil:", agd[agd['K'] > 200]['label'].unique())
print("Crops that required very High RainFall:", agd[agd['rainfall'] > 250]['label'].unique())
print("Crops that required very High Temperature:", agd[agd['temperature'] > 40]['label'].unique())
print("Crops that require very Low Temperature:", agd[agd['temperature'] > 40]['label'].unique())
print("Crops that require very Low Humidity:", agd[agd['humidity'] < 20]['label'].unique())
print("Crops that require very Low pH:", agd[agd['ph'] < 4]['label'].unique())
print("Crops that require very High pH:", agd[agd['ph'] > 9]['label'].unique())
# Out:
# Some Interesting Patterns
# ...........................................
# Crops that require very High Ratio of Nitrogen Content in Soil: ['cotton']
# Crops that require ver High Ratio of Phosphorous Content in Soil: ['grapes' 'apple']
# Crops thet required very High Ratio of Potassium Content in Soil: ['grapes' 'apple']
# Crops that required very High RainFall: ['rice']
# Crops that required very High Temperature: ['grapes' 'papaya']
# Crops that require very Low Temperature: ['grapes' 'papaya']
# Crops that require very Low Humidity: ['chickpea' 'kidneybeans']
# Crops that require very Low pH: ['mothbeans']
# Crops that require very High pH: ['mothbeans']

# %%
#Rainfall vs. Crop Type Distribution
plt.figure(figsize=(12, 6))
sns.boxplot(x='label', y='rainfall', data=agd , color='g')
plt.xticks(rotation=90)
plt.title('Rainfall vs. Crop Type')
plt.show()

# %%
#Checking which crop to be grown according to the season
print("Summer Crops")
print(agd[(agd['temperature'] > 30) & (agd['humidity'] >50)]['label'].unique())
print('----------------------------------------------------------------------')
print("Winter Crops")
print(agd[(agd['temperature'] < 20) & (agd['humidity'] > 30)]['label'].unique())
print('----------------------------------------------------------------------')
print("Monsoon Crops")
print(agd[(agd['rainfall'] > 200) & (agd['humidity'] > 30)]['label'].unique())
# Out:
# Summer Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# ----------------------------------------------------------------------
# Winter Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# ----------------------------------------------------------------------
# Monsoon Crops
# ['rice' 'papaya' 'coconut']

# %%
from sklearn.cluster import KMeans

# %%
#Removing the label Column
x=agd.drop('label' , axis='columns')

# %%
# selecting all the values of data
x=x.values

# %%
print("No of Columns in x :" , x.shape[0])
print("No of Rows in x :" , x.shape[1])
# Out:
# No of Columns in x : 2200
# No of Rows in x : 7

# %% [markdown]
# # Elbow Method

# %%
plt.rcParams['figure.figsize'] = (10,5)

wc=[]
for i in range(1,11):
    km=KMeans(n_clusters=i , init='k-means++' , max_iter=2000 , n_init=10 , random_state=10)
    km.fit(x)
    wc.append(km.inertia_)

#Plotting the results
plt.plot(range(1,11),wc)
plt.title("Elbow Method")
plt.xlabel('No of Clusters')
plt.ylabel('wc')
# Out:
# Text(0, 0.5, 'wc')

# %%
#Implementation of K Means algorithm to perform Clustering analysis

km = KMeans(n_clusters = 4, init = 'k-means++',  max_iter = 2000, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

# %%
#Finding the results
a = agd['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means, a], axis = 1)
z = z.rename(columns = {0: 'cluster'})

# %%
z.head(5)
# Out:
#    cluster label
# 0        3  rice
# 1        3  rice
# 2        3  rice
# 3        3  rice
# 4        3  rice

# %%
#Checking the clusters for each crop
print("Lets Check the results after applying K Means Clustering Analysis \n")
print("Crops in First Cluster:", z[z['cluster'] == 0]['label'].unique())
print("...........................................")
print("Crops in Second Cluster:", z[z['cluster'] == 1]['label'].unique())
print("...........................................")
print("Crops in Third Cluster:", z[z['cluster'] == 2]['label'].unique())
print("...........................................")
print("Crops in Fourth Cluster:", z[z['cluster'] == 3]['label'].unique())
# Out:
# Lets Check the results after applying K Means Clustering Analysis
#
# Crops in First Cluster: ['grapes' 'apple']
# ...........................................
# Crops in Second Cluster: ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ...........................................
# Crops in Third Cluster: ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# ...........................................
# Crops in Fourth Cluster: ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']

# %%
#Splitting the Dataset for predictive modelling

y = agd['label']
x = agd.drop(['label'], axis=1)

print("Shape of x:", x.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of x: (2200, 7)
# Shape of y: (2200,)

# %%
#Creating training and testing sets for results validation

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

print("The Shape Of x train:", x_train.shape)
print("The Shape Of x test:", x_test.shape)
print("The Shape Of y train:", y_train.shape)
print("The Shape Of y test:", y_test.shape)
# Out:
# The Shape Of x train: (1760, 7)
# The Shape Of x test: (440, 7)
# The Shape Of y train: (1760,)
# The Shape Of y test: (440,)

# %%
#Creating a Predictive Model

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# c:\Users\aquib\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Evaluating the model performance
from sklearn.metrics import confusion_matrix

#Printing the Confusing Matrix
plt.rcParams['figure.figsize'] = (10,10)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cmap = 'Wistia')
plt.title('Confusion Matrix For Logistic Regression', fontsize = 15)
plt.show()

# %%
#Defining the classification Report
from sklearn.metrics import classification_report

#Printing the Classification Report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.86      0.82      0.84        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.89      1.00      0.94        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.84      1.00      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.94      0.94        17
#        maize       0.94      0.89      0.91        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.92      0.90        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
#head of dataset
agd.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
prediction = model.predict((np.array([[90, 40, 40, 20, 80, 7, 200]])))
print("The Suggested Crop for given climatic condition is :",prediction)
# Out:
# The Suggested Crop for given climatic condition is : ['rice']
# c:\Users\aquib\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
model.score(x,y)
# Out:
# 0.9690909090909091
